# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
pwd
# Out:
# 'C:\\Users\\dbda\\Desktop\\Suchandra & Ajitesh\\Machine Learning\\Day-4'

# %%
df = pd.read_csv(r"C:\Users\dbda\Desktop\Suchandra & Ajitesh\Machine Learning\Day-4\Flightcharges.csv.csv")
df
# Out:
#         airline  distance business class economy class rush hr  price
# 0        indigo      1200             no           yes     yes  10000
# 1       vistara      1250             no           yes     yes  12000
# 2     air india      2300            yes            no     yes  20000
# 3      emirates      1542            yes            no     yes  25000
# 4        nippon      1248            yes            no     yes  23000
# 5       raynair      1265            yes            no      no  14000
# 6        spirit      2415             no           yes      no  15000
# 7        united      8521            yes            no      no  25100
# 8      air asia      3652            yes            no      no  14785
# 9   king fisher      4520             no           yes      no   4512
# 10      eithaid      9521            yes            no      no  32561
# 11        qatar      1478            yes            no     yes  18000
# ...

# %%
df['business class'] = df['business class'].map({'yes': 1, 'no': 0})
df['economy class'] = df['economy class'].map({'yes': 1, 'no': 0})
df['rush hr'] = df['rush hr'].map({'yes': 1, 'no': 0})

# %%
df
# Out:
#         airline  distance  business class  economy class  rush hr  price
# 0        indigo      1200               0              1        1  10000
# 1       vistara      1250               0              1        1  12000
# 2     air india      2300               1              0        1  20000
# 3      emirates      1542               1              0        1  25000
# 4        nippon      1248               1              0        1  23000
# 5       raynair      1265               1              0        0  14000
# 6        spirit      2415               0              1        0  15000
# 7        united      8521               1              0        0  25100
# 8      air asia      3652               1              0        0  14785
# 9   king fisher      4520               0              1        0   4512
# 10      eithaid      9521               1              0        0  32561
# 11        qatar      1478               1              0        1  18000
# ...

# %%
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(df.corr(), annot= True)
plt.show()
