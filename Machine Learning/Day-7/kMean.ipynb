# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, r2_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv(r"C:\Users\AJITESH\Desktop\Day-7\income.csv")
df
# Out:
#         Name  Age  Income($)
# 0        Rob   27      70000
# 1    Michael   29      90000
# 2      Mohan   29      61000
# 3     Ismail   28      60000
# 4       Kory   42     150000
# 5     Gautam   39     155000
# 6      David   41     160000
# 7     Andrea   38     162000
# 8       Brad   36     156000
# 9   Angelina   35     130000
# 10    Donald   37     137000
# 11       Tom   26      45000
# 12    Arnold   27      48000
# 13     Jared   28      51000
# 14     Stark   29      49500
# 15    Ranbir   32      53000
# 16    Dipika   40      65000
# 17  Priyanka   41      63000
# 18      Nick   43      64000
# 19      Alia   39      80000
# 20       Sid   41      82000
# 21     Abdul   39      58000

# %%
x = np.array(df['Age']).reshape(-1,1)
y = np.array(df['Income($)']).reshape(-1,1)

# %%
plt.scatter(x,y)

# %%
model = KMeans()

# %%
model.fit(x,y)
# Out:
# C:\Users\AJITESH\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans()

# %%
yhat = model.predict(x,y)
yhat
# Out:
# C:\Users\AJITESH\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1102: FutureWarning: 'sample_weight' was deprecated in version 1.3 and will be removed in 1.5.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 yhat = model.predict(x,y)
#       2 yhat
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1109, in _BaseKMeans.predict(self, X, sample_weight)
#    1101 if not (isinstance(sample_weight, str) and sample_weight == "deprecated"):
#    1102     warnings.warn(
#    1103         (
#    1104             "'sample_weight' was deprecated in version 1.3 and "
#    (...)
#    1107         FutureWarning,
#    1108     )
# -> 1109     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#    1110 else:
#    1111     sample_weight = _check_sample_weight(None, X, dtype=X.dtype)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2014, in _check_sample_weight(sample_weight, X, dtype, copy, only_non_negative)
#    2004 sample_weight = check_array(
#    2005     sample_weight,
#    2006     accept_sparse=False,
#    (...)
#    2011     input_name="sample_weight",
#    2012 )
#    2013 if sample_weight.ndim != 1:
# -> 2014     raise ValueError("Sample weights must be 1D array or scalar")
#    2016 if sample_weight.shape != (n_samples,):
#    2017     raise ValueError(
#    2018         "sample_weight.shape == {}, expected {}!".format(
#    2019             sample_weight.shape, (n_samples,)
#    2020         )
#    2021     )
#
# ValueError: Sample weights must be 1D array or scalar

# %%
df['cluster'] = yhat
df

# %%
scaler = MinMaxScaler()
scaler.fit(y)
y == scaler.transform(y)
y
